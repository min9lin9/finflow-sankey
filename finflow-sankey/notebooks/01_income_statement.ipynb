# %% [markdown]
# # FinFlow Sankey: Income Statement Basics
#
# This notebook shows how to build an income statement Sankey from a Polars DataFrame.

# %%
import polars as pl
from finflow_sankey import FinancialSankey

# %% [markdown]
# ## 1. Prepare data

# %%
df = pl.DataFrame({
    "account": ["Revenue", "Cost of Revenue", "Operating Expenses", "Tax", "Net Income"],
    "value": [100_000_000.0, -40_000_000.0, -30_000_000.0, -10_000_000.0, 20_000_000.0],
    "period": ["FY2025"] * 5,
    "currency": ["USD"] * 5,
    "statement": ["income_statement"] * 5,
    "section": ["revenue", "cost_of_revenue", "operating_expenses", "tax", "profit"],
})
df

# %% [markdown]
# ## 2. Render Sankey

# %%
fig = (
    FinancialSankey.income_statement(df, period="FY2025", currency="USD")
    .validate()
    .render(title="FY2025 Income Statement")
)
fig.show()

# %% [markdown]
# ## 3. Export to HTML

# %%
FinancialSankey.income_statement(df).validate().export_html(
    "income_statement.html", title="FY2025 Income Statement"
)
